# %%
#6.1.4

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#6.1.5

# %%
#Import the citpy dependency
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 579

# %%
#6.2.2

# %%
import requests
requests.__version__
# Out:
# '2.28.1'

# %%
#6.2.3

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#6.2.6

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(120)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | harper
# Processing Record 2 of Set 1 | college
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | leninskoye
# Processing Record 7 of Set 1 | tazovskiy
# Processing Record 8 of Set 1 | narsaq
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | baghdad
# Processing Record 11 of Set 1 | sorland
# Processing Record 12 of Set 1 | belmonte
# Processing Record 13 of Set 1 | comodoro rivadavia
# Processing Record 14 of Set 1 | najran
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | requena
# Processing Record 21 of Set 1 | kavieng
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | namatanai
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | ukiah
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | zhezkazgan
# Processing Record 31 of Set 1 | alofi
# Processing Record 32 of Set 1 | sabha
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | urcos
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | jalu
# Processing Record 37 of Set 1 | seryshevo
# Processing Record 38 of Set 1 | rocha
# Processing Record 39 of Set 1 | aklavik
# Processing Record 40 of Set 1 | mildura
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | burns lake
# Processing Record 43 of Set 1 | tuatapere
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | fomboni
# Processing Record 46 of Set 1 | kulhudhuffushi
# Processing Record 47 of Set 1 | chardara
# Processing Record 48 of Set 1 | lavrentiya
# Processing Record 49 of Set 1 | mount darwin
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | lovozero
# Processing Record 2 of Set 2 | tilichiki
# Processing Record 3 of Set 2 | viedma
# Processing Record 4 of Set 2 | alta floresta
# Processing Record 5 of Set 2 | amurrio
# Processing Record 6 of Set 2 | sioux lookout
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | saldanha
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | knappskog
# Processing Record 16 of Set 2 | ushuaia
# Processing Record 17 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | leh
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | vanavara
# Processing Record 22 of Set 2 | khovu-aksy
# Processing Record 23 of Set 2 | holme
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | belaya gora
# Processing Record 26 of Set 2 | cap malheureux
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | luderitz
# Processing Record 29 of Set 2 | makakilo city
# Processing Record 30 of Set 2 | provideniya
# Processing Record 31 of Set 2 | yar-sale
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | cayenne
# Processing Record 34 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 35 of Set 2 | susanville
# Processing Record 36 of Set 2 | mnogovershinnyy
# Processing Record 37 of Set 2 | truckee
# Processing Record 38 of Set 2 | kabo
# Processing Record 39 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 2 | srednekolymsk
# Processing Record 41 of Set 2 | japura
# Processing Record 42 of Set 2 | torit
# Processing Record 43 of Set 2 | bethel
# Processing Record 44 of Set 2 | atka
# City not found. Skipping...
# Processing Record 45 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 2 | chastoozerye
# City not found. Skipping...
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 2 | kumylzhenskaya
# Processing Record 50 of Set 2 | luzhou
# Processing Record 1 of Set 3 | salalah
# Processing Record 2 of Set 3 | takoradi
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | malatya
# Processing Record 6 of Set 3 | necochea
# Processing Record 7 of Set 3 | sorong
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | ostrovnoy
# Processing Record 10 of Set 3 | buraydah
# Processing Record 11 of Set 3 | badarpur
# Processing Record 12 of Set 3 | camapua
# Processing Record 13 of Set 3 | balaipungut
# Processing Record 14 of Set 3 | gunjur
# Processing Record 15 of Set 3 | hasaki
# Processing Record 16 of Set 3 | zanjan
# Processing Record 17 of Set 3 | san patricio
# Processing Record 18 of Set 3 | rio cuarto
# Processing Record 19 of Set 3 | carnarvon
# Processing Record 20 of Set 3 | shache
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | launceston
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | otane
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | ancud
# Processing Record 27 of Set 3 | balch springs
# Processing Record 28 of Set 3 | haines junction
# Processing Record 29 of Set 3 | broome
# Processing Record 30 of Set 3 | roald
# Processing Record 31 of Set 3 | new norfolk
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | sarh
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | saint-philippe
# Processing Record 36 of Set 3 | vryburg
# Processing Record 37 of Set 3 | gushikawa
# Processing Record 38 of Set 3 | sept-iles
# Processing Record 39 of Set 3 | mocuba
# Processing Record 40 of Set 3 | alice springs
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | port victoria
# Processing Record 43 of Set 3 | cockburn town
# Processing Record 44 of Set 3 | opuwo
# Processing Record 45 of Set 3 | rio grande
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | los algarrobos
# Processing Record 48 of Set 3 | charagua
# Processing Record 49 of Set 3 | laguna
# Processing Record 50 of Set 3 | east london
# Processing Record 1 of Set 4 | sinnamary
# Processing Record 2 of Set 4 | koutiala
# Processing Record 3 of Set 4 | koslan
# Processing Record 4 of Set 4 | huanren
# Processing Record 5 of Set 4 | ust-omchug
# Processing Record 6 of Set 4 | salinas
# Processing Record 7 of Set 4 | katsuura
# Processing Record 8 of Set 4 | thinadhoo
# Processing Record 9 of Set 4 | penzance
# Processing Record 10 of Set 4 | kruisfontein
# Processing Record 11 of Set 4 | tura
# Processing Record 12 of Set 4 | neuquen
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | esperance
# Processing Record 15 of Set 4 | kamina
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | taywarah
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | namibe
# Processing Record 20 of Set 4 | dikson
# Processing Record 21 of Set 4 | cranbrook
# Processing Record 22 of Set 4 | shubarshi
# Processing Record 23 of Set 4 | altamira
# Processing Record 24 of Set 4 | sao filipe
# Processing Record 25 of Set 4 | vila franca do campo
# Processing Record 26 of Set 4 | grand gaube
# Processing Record 27 of Set 4 | sidi ali
# Processing Record 28 of Set 4 | vaitape
# Processing Record 29 of Set 4 | airai
# Processing Record 30 of Set 4 | reyes
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | beroroha
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | tasiilaq
# Processing Record 35 of Set 4 | santa cruz del norte
# Processing Record 36 of Set 4 | hanzhong
# Processing Record 37 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 4 | hami
# Processing Record 39 of Set 4 | batagay-alyta
# Processing Record 40 of Set 4 | ola
# Processing Record 41 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 4 | paita
# Processing Record 43 of Set 4 | khoy
# Processing Record 44 of Set 4 | capaci
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | nikolskoye
# Processing Record 47 of Set 4 | pangody
# Processing Record 48 of Set 4 | granada
# Processing Record 49 of Set 4 | ballina
# Processing Record 50 of Set 4 | mayo
# Processing Record 1 of Set 5 | taiyuan
# Processing Record 2 of Set 5 | lakes entrance
# Processing Record 3 of Set 5 | asosa
# Processing Record 4 of Set 5 | benghazi
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | luganville
# Processing Record 7 of Set 5 | ponta do sol
# Processing Record 8 of Set 5 | angol
# Processing Record 9 of Set 5 | mehamn
# Processing Record 10 of Set 5 | clyde river
# Processing Record 11 of Set 5 | port lincoln
# Processing Record 12 of Set 5 | faya
# Processing Record 13 of Set 5 | sulangan
# Processing Record 14 of Set 5 | rawson
# Processing Record 15 of Set 5 | caravelas
# Processing Record 16 of Set 5 | watrous
# Processing Record 17 of Set 5 | abu road
# Processing Record 18 of Set 5 | skegness
# Processing Record 19 of Set 5 | nagato
# Processing Record 20 of Set 5 | quimper
# Processing Record 21 of Set 5 | nelson
# Processing Record 22 of Set 5 | hamilton
# Processing Record 23 of Set 5 | buan
# Processing Record 24 of Set 5 | manta
# Processing Record 25 of Set 5 | padang
# Processing Record 26 of Set 5 | kutina
# Processing Record 27 of Set 5 | camacha
# Processing Record 28 of Set 5 | oktyabrskiy
# Processing Record 29 of Set 5 | zielona gora
# Processing Record 30 of Set 5 | tommot
# Processing Record 31 of Set 5 | kongolo
# Processing Record 32 of Set 5 | alberton
# Processing Record 33 of Set 5 | puerto leguizamo
# Processing Record 34 of Set 5 | riyadh
# Processing Record 35 of Set 5 | dingle
# Processing Record 36 of Set 5 | margate
# Processing Record 37 of Set 5 | gossaigaon
# Processing Record 38 of Set 5 | pacific grove
# Processing Record 39 of Set 5 | tansen
# Processing Record 40 of Set 5 | sabang
# Processing Record 41 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 5 | el alto
# Processing Record 43 of Set 5 | mar del plata
# Processing Record 44 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 5 | akureyri
# Processing Record 46 of Set 5 | upernavik
# Processing Record 47 of Set 5 | morant bay
# Processing Record 48 of Set 5 | husavik
# Processing Record 49 of Set 5 | lompoc
# Processing Record 50 of Set 5 | vostok
# Processing Record 1 of Set 6 | misratah
# Processing Record 2 of Set 6 | iwanai
# Processing Record 3 of Set 6 | jonesboro
# Processing Record 4 of Set 6 | chapada dos guimaraes
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | farmington
# Processing Record 7 of Set 6 | souillac
# Processing Record 8 of Set 6 | tiznit
# Processing Record 9 of Set 6 | usinsk
# Processing Record 10 of Set 6 | codrington
# Processing Record 11 of Set 6 | coquimbo
# Processing Record 12 of Set 6 | anadyr
# Processing Record 13 of Set 6 | pangnirtung
# Processing Record 14 of Set 6 | glazov
# Processing Record 15 of Set 6 | pisco
# Processing Record 16 of Set 6 | yabrud
# Processing Record 17 of Set 6 | shieli
# Processing Record 18 of Set 6 | kambove
# Processing Record 19 of Set 6 | borodino
# Processing Record 20 of Set 6 | flinders
# Processing Record 21 of Set 6 | nakamura
# Processing Record 22 of Set 6 | ascension
# Processing Record 23 of Set 6 | tuktoyaktuk
# Processing Record 24 of Set 6 | verkhnyaya inta
# Processing Record 25 of Set 6 | carballo
# Processing Record 26 of Set 6 | erenhot
# Processing Record 27 of Set 6 | shingu
# Processing Record 28 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 29 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 6 | fuyu
# Processing Record 31 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 6 | takaungu
# Processing Record 33 of Set 6 | sretensk
# Processing Record 34 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 6 | gandajika
# Processing Record 36 of Set 6 | noumea
# Processing Record 37 of Set 6 | kralendijk
# Processing Record 38 of Set 6 | lobito
# Processing Record 39 of Set 6 | half moon bay
# Processing Record 40 of Set 6 | pakaur
# Processing Record 41 of Set 6 | inhambane
# Processing Record 42 of Set 6 | kerchevskiy
# Processing Record 43 of Set 6 | itarema
# Processing Record 44 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 45 of Set 6 | kushima
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | hofn
# Processing Record 48 of Set 6 | stromness
# Processing Record 49 of Set 6 | bria
# Processing Record 50 of Set 6 | pocoes
# Processing Record 1 of Set 7 | paka
# Processing Record 2 of Set 7 | port-cartier
# Processing Record 3 of Set 7 | marzuq
# Processing Record 4 of Set 7 | sampit
# Processing Record 5 of Set 7 | san quintin
# Processing Record 6 of Set 7 | prince rupert
# Processing Record 7 of Set 7 | puerto madryn
# Processing Record 8 of Set 7 | torbay
# Processing Record 9 of Set 7 | severo-kurilsk
# Processing Record 10 of Set 7 | saint-augustin
# Processing Record 11 of Set 7 | byron bay
# Processing Record 12 of Set 7 | gospic
# Processing Record 13 of Set 7 | cabedelo
# Processing Record 14 of Set 7 | canon city
# Processing Record 15 of Set 7 | hervey bay
# Processing Record 16 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 7 | tambul
# City not found. Skipping...
# Processing Record 18 of Set 7 | palu
# Processing Record 19 of Set 7 | kurilsk
# Processing Record 20 of Set 7 | norman wells
# Processing Record 21 of Set 7 | platonovka
# Processing Record 22 of Set 7 | ketchikan
# Processing Record 23 of Set 7 | berlevag
# Processing Record 24 of Set 7 | riverton
# Processing Record 25 of Set 7 | nacala
# Processing Record 26 of Set 7 | chokurdakh
# Processing Record 27 of Set 7 | leningradskiy
# Processing Record 28 of Set 7 | macamic
# Processing Record 29 of Set 7 | conceicao da barra
# Processing Record 30 of Set 7 | vao
# Processing Record 31 of Set 7 | horadiz
# Processing Record 32 of Set 7 | katherine
# Processing Record 33 of Set 7 | kodiak
# Processing Record 34 of Set 7 | davila
# Processing Record 35 of Set 7 | angoram
# Processing Record 36 of Set 7 | fortuna
# Processing Record 37 of Set 7 | luau
# Processing Record 38 of Set 7 | birao
# Processing Record 39 of Set 7 | charcas
# Processing Record 40 of Set 7 | peremyshlyany
# Processing Record 41 of Set 7 | bubaque
# Processing Record 42 of Set 7 | jining
# Processing Record 43 of Set 7 | siguiri
# Processing Record 44 of Set 7 | lichtenburg
# Processing Record 45 of Set 7 | richards bay
# Processing Record 46 of Set 7 | puerto penasco
# Processing Record 47 of Set 7 | wenling
# Processing Record 48 of Set 7 | bandarbeyla
# Processing Record 49 of Set 7 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 50 of Set 7 | magadan
# Processing Record 1 of Set 8 | vila velha
# Processing Record 2 of Set 8 | bengkulu
# Processing Record 3 of Set 8 | atyrau
# Processing Record 4 of Set 8 | hauterive
# Processing Record 5 of Set 8 | broken hill
# Processing Record 6 of Set 8 | kichera
# Processing Record 7 of Set 8 | olafsvik
# Processing Record 8 of Set 8 | naze
# Processing Record 9 of Set 8 | vinh
# Processing Record 10 of Set 8 | sobradinho
# Processing Record 11 of Set 8 | saint-francois
# Processing Record 12 of Set 8 | cabo san lucas
# Processing Record 13 of Set 8 | kollam
# Processing Record 14 of Set 8 | dhari
# Processing Record 15 of Set 8 | rio gallegos
# Processing Record 16 of Set 8 | ulladulla
# Processing Record 17 of Set 8 | krupina
# Processing Record 18 of Set 8 | lima
# Processing Record 19 of Set 8 | san cristobal
# Processing Record 20 of Set 8 | marsa matruh
# Processing Record 21 of Set 8 | ler
# Processing Record 22 of Set 8 | newport
# Processing Record 23 of Set 8 | marawi
# Processing Record 24 of Set 8 | klaksvik
# Processing Record 25 of Set 8 | siemiatycze
# Processing Record 26 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 8 | boyolangu
# Processing Record 28 of Set 8 | yinchuan
# Processing Record 29 of Set 8 | ilesha
# Processing Record 30 of Set 8 | waddan
# Processing Record 31 of Set 8 | henties bay
# Processing Record 32 of Set 8 | leshukonskoye
# Processing Record 33 of Set 8 | port hedland
# Processing Record 34 of Set 8 | sterling
# Processing Record 35 of Set 8 | turbat
# Processing Record 36 of Set 8 | harer
# Processing Record 37 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 8 | isangel
# Processing Record 39 of Set 8 | poum
# Processing Record 40 of Set 8 | farafangana
# Processing Record 41 of Set 8 | verdalsora
# City not found. Skipping...
# Processing Record 42 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 8 | trincomalee
# Processing Record 44 of Set 8 | mwinilunga
# Processing Record 45 of Set 8 | karakol
# Processing Record 46 of Set 8 | marrakesh
# Processing Record 47 of Set 8 | touros
# Processing Record 48 of Set 8 | surt
# Processing Record 49 of Set 8 | nishihara
# Processing Record 50 of Set 8 | faanui
# Processing Record 1 of Set 9 | le port
# Processing Record 2 of Set 9 | kaeo
# Processing Record 3 of Set 9 | komsomolskiy
# Processing Record 4 of Set 9 | severnyy
# Processing Record 5 of Set 9 | sipoo
# Processing Record 6 of Set 9 | tual
# Processing Record 7 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 9 | pawai
# Processing Record 9 of Set 9 | bambous virieux
# Processing Record 10 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 11 of Set 9 | calvinia
# Processing Record 12 of Set 9 | cherskiy
# Processing Record 13 of Set 9 | iquique
# Processing Record 14 of Set 9 | bowen
# Processing Record 15 of Set 9 | kurikka
# Processing Record 16 of Set 9 | longyearbyen
# Processing Record 17 of Set 9 | kalmunai
# Processing Record 18 of Set 9 | francistown
# Processing Record 19 of Set 9 | grindavik
# Processing Record 20 of Set 9 | ruston
# Processing Record 21 of Set 9 | victor harbor
# Processing Record 22 of Set 9 | gillette
# Processing Record 23 of Set 9 | kulachi
# Processing Record 24 of Set 9 | venice
# Processing Record 25 of Set 9 | shevchenkove
# Processing Record 26 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 9 | ust-maya
# Processing Record 28 of Set 9 | monte alto
# Processing Record 29 of Set 9 | aluksne
# Processing Record 30 of Set 9 | tromso
# Processing Record 31 of Set 9 | dukat
# Processing Record 32 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 33 of Set 9 | saint anthony
# Processing Record 34 of Set 9 | muros
# Processing Record 35 of Set 9 | avanigadda
# Processing Record 36 of Set 9 | bilibino
# Processing Record 37 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 9 | blois
# Processing Record 39 of Set 9 | nyagan
# Processing Record 40 of Set 9 | axim
# Processing Record 41 of Set 9 | hualmay
# Processing Record 42 of Set 9 | kresttsy
# Processing Record 43 of Set 9 | poronaysk
# Processing Record 44 of Set 9 | kohima
# Processing Record 45 of Set 9 | kahului
# Processing Record 46 of Set 9 | the valley
# Processing Record 47 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 9 | capim grosso
# Processing Record 49 of Set 9 | shakawe
# Processing Record 50 of Set 9 | jarabacoa
# Processing Record 1 of Set 10 | dalnegorsk
# Processing Record 2 of Set 10 | nyimba
# Processing Record 3 of Set 10 | gebre guracha
# Processing Record 4 of Set 10 | beringovskiy
# Processing Record 5 of Set 10 | pueblo nuevo
# Processing Record 6 of Set 10 | vanimo
# Processing Record 7 of Set 10 | seymchan
# Processing Record 8 of Set 10 | tshela
# Processing Record 9 of Set 10 | lyman
# Processing Record 10 of Set 10 | dutlwe
# Processing Record 11 of Set 10 | hurghada
# Processing Record 12 of Set 10 | pandan
# Processing Record 13 of Set 10 | esfarayen
# Processing Record 14 of Set 10 | lagoa
# Processing Record 15 of Set 10 | vestmannaeyjar
# Processing Record 16 of Set 10 | cairns
# Processing Record 17 of Set 10 | pueblo
# Processing Record 18 of Set 10 | belgatoy
# Processing Record 19 of Set 10 | yulara
# Processing Record 20 of Set 10 | mogadishu
# Processing Record 21 of Set 10 | pangkalanbuun
# Processing Record 22 of Set 10 | umea
# Processing Record 23 of Set 10 | durusu
# Processing Record 24 of Set 10 | yermakovskoye
# Processing Record 25 of Set 10 | baculin
# Processing Record 26 of Set 10 | mount isa
# Processing Record 27 of Set 10 | yeppoon
# Processing Record 28 of Set 10 | sao joao do paraiso
# Processing Record 29 of Set 10 | dudinka
# Processing Record 30 of Set 10 | nago
# Processing Record 31 of Set 10 | gusau
# Processing Record 32 of Set 10 | vung tau
# Processing Record 33 of Set 10 | strezhevoy
# Processing Record 34 of Set 10 | dubbo
# Processing Record 35 of Set 10 | poopo
# Processing Record 36 of Set 10 | pyaozerskiy
# Processing Record 37 of Set 10 | bend
# Processing Record 38 of Set 10 | bairiki
# Processing Record 39 of Set 10 | mirnyy
# Processing Record 40 of Set 10 | acarau
# Processing Record 41 of Set 10 | gigmoto
# Processing Record 42 of Set 10 | yei
# Processing Record 43 of Set 10 | tottori
# Processing Record 44 of Set 10 | concepcion
# Processing Record 45 of Set 10 | mercedes
# Processing Record 46 of Set 10 | paamiut
# Processing Record 47 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 48 of Set 10 | berbera
# Processing Record 49 of Set 10 | harpalpur
# Processing Record 50 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 2 of Set 11 | latung
# Processing Record 3 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 11 | nohar
# Processing Record 6 of Set 11 | luanda
# Processing Record 7 of Set 11 | billings
# Processing Record 8 of Set 11 | lasa
# Processing Record 9 of Set 11 | san pedro
# Processing Record 10 of Set 11 | nizhneudinsk
# Processing Record 11 of Set 11 | asau
# Processing Record 12 of Set 11 | qui nhon
# Processing Record 13 of Set 11 | arras
# Processing Record 14 of Set 11 | jurado
# Processing Record 15 of Set 11 | karasjok
# Processing Record 16 of Set 11 | riachao do jacuipe
# Processing Record 17 of Set 11 | prado
# Processing Record 18 of Set 11 | lorengau
# Processing Record 19 of Set 11 | gasa
# Processing Record 20 of Set 11 | kedrovyy
# Processing Record 21 of Set 11 | barcelona
# Processing Record 22 of Set 11 | maniitsoq
# Processing Record 23 of Set 11 | mancora
# Processing Record 24 of Set 11 | puksoozero
# Processing Record 25 of Set 11 | reconquista
# Processing Record 26 of Set 11 | langxiang
# Processing Record 27 of Set 11 | soto la marina
# Processing Record 28 of Set 11 | urucara
# Processing Record 29 of Set 11 | scarborough
# Processing Record 30 of Set 11 | tahoua
# Processing Record 31 of Set 11 | atar
# Processing Record 32 of Set 11 | ozu
# Processing Record 33 of Set 11 | vardo
# Processing Record 34 of Set 11 | russellville
# Processing Record 35 of Set 11 | puerto escondido
# Processing Record 36 of Set 11 | nemuro
# Processing Record 37 of Set 11 | tokmak
# Processing Record 38 of Set 11 | samarkand
# Processing Record 39 of Set 11 | te anau
# Processing Record 40 of Set 11 | ahipara
# Processing Record 41 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 11 | pareora
# Processing Record 43 of Set 11 | agirish
# Processing Record 44 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 11 | boa vista
# Processing Record 46 of Set 11 | hambantota
# Processing Record 47 of Set 11 | lata
# Processing Record 48 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 49 of Set 11 | skjervoy
# Processing Record 50 of Set 11 | narasannapeta
# Processing Record 1 of Set 12 | osoyoos
# Processing Record 2 of Set 12 | jiblah
# Processing Record 3 of Set 12 | karaton
# Processing Record 4 of Set 12 | mayor pablo lagerenza
# Processing Record 5 of Set 12 | phonhong
# Processing Record 6 of Set 12 | lewistown
# Processing Record 7 of Set 12 | santiago del estero
# Processing Record 8 of Set 12 | omboue
# Processing Record 9 of Set 12 | santiago de cao
# Processing Record 10 of Set 12 | salina cruz
# Processing Record 11 of Set 12 | melton
# Processing Record 12 of Set 12 | biak
# Processing Record 13 of Set 12 | cidreira
# Processing Record 14 of Set 12 | salinopolis
# Processing Record 15 of Set 12 | evanston
# Processing Record 16 of Set 12 | boundiali
# Processing Record 17 of Set 12 | mpwapwa
# Processing Record 18 of Set 12 | lensk
# Processing Record 19 of Set 12 | havre-saint-pierre
# Processing Record 20 of Set 12 | moulmeingyun
# City not found. Skipping...
# Processing Record 21 of Set 12 | paraiso
# Processing Record 22 of Set 12 | doha
# Processing Record 23 of Set 12 | de aar
# Processing Record 24 of Set 12 | acapulco
# Processing Record 25 of Set 12 | charters towers
# Processing Record 26 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 12 | hisor
# Processing Record 28 of Set 12 | saint-pierre
# Processing Record 29 of Set 12 | lolua
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Harper   4.3750   -7.7169     78.15        82          76        6.06
# 1     College  64.8569 -147.8028     14.32        87         100        6.91
# 2    Hermanus -34.4187   19.2345     58.80        54          93        8.68
# 3    Thompson  55.7435  -97.8558     24.96        80          75       10.36
# 4     Rikitea -23.1203 -134.9692     74.46        82         100       10.67
# 5  Leninskoye  41.7589   69.3864     49.69        45          98        4.21
# 6   Tazovskiy  67.4667   78.7000    -33.23       100          19        3.53
# 7      Narsaq  60.9167  -46.0500     21.38        65          18       11.59
# 8        Lebu -37.6167  -73.6500     58.93        71         100       20.24
# 9     Baghdad  33.3406   44.4009     69.71        46          75       12.66
#
#   Country                 Date
# 0      LR  2022-11-24 20:52:42
# 1      US  2022-11-24 20:52:42
# 2      ZA  2022-11-24 20:52:43
# 3      CA  2022-11-24 20:52:43
# 4      PF  2022-11-24 20:52:43
# 5      KZ  2022-11-24 20:52:44
# 6      RU  2022-11-24 20:52:44
# 7      GL  2022-11-24 20:52:45
# 8      CL  2022-11-24 20:52:45
# 9      IQ  2022-11-24 20:51:18

# %%
#6.2.7

# %%
#Create an array with the order of the columns we want in the output 
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
#Create a new data frame with the new column order and display
newcity_data_file = city_data_df[new_column_order]
newcity_data_file.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0      Harper      LR  2022-11-24 20:52:42   4.3750   -7.7169     78.15
# 1     College      US  2022-11-24 20:52:42  64.8569 -147.8028     14.32
# 2    Hermanus      ZA  2022-11-24 20:52:43 -34.4187   19.2345     58.80
# 3    Thompson      CA  2022-11-24 20:52:43  55.7435  -97.8558     24.96
# 4     Rikitea      PF  2022-11-24 20:52:43 -23.1203 -134.9692     74.46
# 5  Leninskoye      KZ  2022-11-24 20:52:44  41.7589   69.3864     49.69
# 6   Tazovskiy      RU  2022-11-24 20:52:44  67.4667   78.7000    -33.23
# 7      Narsaq      GL  2022-11-24 20:52:45  60.9167  -46.0500     21.38
# 8        Lebu      CL  2022-11-24 20:52:45 -37.6167  -73.6500     58.93
# 9     Baghdad      IQ  2022-11-24 20:51:18  33.3406   44.4009     69.71
#
#    Humidity  Cloudiness  Wind Speed
# 0        82          76        6.06
# 1        87         100        6.91
# 2        54          93        8.68
# 3        80          75       10.36
# 4        82         100       10.67
# 5        45          98        4.21
# 6       100          19        3.53
# 7        65          18       11.59
# 8        71         100       20.24
# 9        46          75       12.66

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
newcity_data_file.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14664\265489882.py in <module>
#       3
#       4 # Export the City_Data into a CSV.
# ----> 5 newcity_data_file.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1178             formatter=self.fmt,
#    1179         )
# -> 1180         csv_formatter.save()
#    1181
#    1182         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     239         """
#     240         # apply compression and byte/text conversion
# --> 241         with get_handle(
#     242             self.filepath_or_buffer,
#     243             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: 'weather_data/cities.csv'

# %%
city_data_df = newcity_data_file
city_data_df
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0             Harper      LR  2022-11-24 20:52:42   4.3750   -7.7169
# 1            College      US  2022-11-24 20:52:42  64.8569 -147.8028
# 2           Hermanus      ZA  2022-11-24 20:52:43 -34.4187   19.2345
# 3           Thompson      CA  2022-11-24 20:52:43  55.7435  -97.8558
# 4            Rikitea      PF  2022-11-24 20:52:43 -23.1203 -134.9692
# ..               ...     ...                  ...      ...       ...
# 529           De Aar      ZA  2022-11-24 21:18:34 -30.6497   24.0123
# 530         Acapulco      MX  2022-11-24 21:18:34  16.8634  -99.8901
# 531  Charters Towers      AU  2022-11-24 21:18:35 -20.1000  146.2667
# 532            Hisor      TJ  2022-11-24 21:18:35  38.5250   68.5512
# 533     Saint-Pierre      RE  2022-11-24 21:18:36 -21.3393   55.4781
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       78.15        82          76        6.06
# 1       14.32        87         100        6.91
# 2       58.80        54          93        8.68
# 3       24.96        80          75       10.36
# 4       74.46        82         100       10.67
# ..        ...       ...         ...         ...
# 529     67.26        20           0        8.81
# 530     85.82        70          75        6.91
# 531     75.20        77          98        8.95
# 532     42.55        35         100        2.91
# 533     73.90        73           0        6.91
#
# [534 rows x 9 columns]

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
