# %%
#6.1.4

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#6.1.5

# %%
#Import the citpy dependency
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 632

# %%
#6.2.2

# %%
import requests
requests.__version__
# Out:
# '2.28.1'

# %%
#6.2.3

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1f11fd4c1124fe0f9effb3158e013dd4

# %%
#6.2.6

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | cayenne
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | bloemhof
# Processing Record 8 of Set 1 | saint george
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | lillooet
# Processing Record 11 of Set 1 | alta floresta
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 1 | half moon bay
# Processing Record 16 of Set 1 | bandarbeyla
# Processing Record 17 of Set 1 | itoman
# Processing Record 18 of Set 1 | orlik
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | grindavik
# Processing Record 21 of Set 1 | desaguadero
# Processing Record 22 of Set 1 | valkeala
# Processing Record 23 of Set 1 | espanola
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | kruisfontein
# Processing Record 27 of Set 1 | teguldet
# Processing Record 28 of Set 1 | vanimo
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | chapais
# Processing Record 31 of Set 1 | kavieng
# Processing Record 32 of Set 1 | tateyama
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | naugarzan
# City not found. Skipping...
# Processing Record 35 of Set 1 | sakakah
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | gushikawa
# Processing Record 39 of Set 1 | hajduboszormeny
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | deputatskiy
# Processing Record 42 of Set 1 | salihli
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | vieste
# Processing Record 45 of Set 1 | palmeira
# Processing Record 46 of Set 1 | vila
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 1 | novoilinskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | avanigadda
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | lata
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | joshimath
# Processing Record 8 of Set 2 | ornskoldsvik
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | neiafu
# Processing Record 12 of Set 2 | kieta
# Processing Record 13 of Set 2 | manama
# Processing Record 14 of Set 2 | morondava
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | ulaangom
# Processing Record 17 of Set 2 | celestun
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 2 | inhambane
# Processing Record 22 of Set 2 | boende
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | yenagoa
# Processing Record 25 of Set 2 | ust-kuyga
# Processing Record 26 of Set 2 | upernavik
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | mount isa
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | zyryanka
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | piacabucu
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | chimore
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | litovko
# Processing Record 37 of Set 2 | mount gambier
# Processing Record 38 of Set 2 | udachnyy
# Processing Record 39 of Set 2 | okha
# Processing Record 40 of Set 2 | sinegorye
# Processing Record 41 of Set 2 | norman wells
# Processing Record 42 of Set 2 | ternate
# Processing Record 43 of Set 2 | nanortalik
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | mpongwe
# Processing Record 46 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 2 | tucurui
# Processing Record 49 of Set 2 | lincoln
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | provideniya
# Processing Record 2 of Set 3 | luderitz
# Processing Record 3 of Set 3 | sitka
# Processing Record 4 of Set 3 | ixtapa
# Processing Record 5 of Set 3 | bathsheba
# Processing Record 6 of Set 3 | buarcos
# Processing Record 7 of Set 3 | alice springs
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | gulu
# Processing Record 11 of Set 3 | carutapera
# Processing Record 12 of Set 3 | paamiut
# Processing Record 13 of Set 3 | tecoanapa
# Processing Record 14 of Set 3 | santa rosa
# Processing Record 15 of Set 3 | dikson
# Processing Record 16 of Set 3 | mehamn
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | avarua
# Processing Record 19 of Set 3 | ayagoz
# Processing Record 20 of Set 3 | richards bay
# Processing Record 21 of Set 3 | jalu
# Processing Record 22 of Set 3 | marquette
# Processing Record 23 of Set 3 | clyde river
# Processing Record 24 of Set 3 | okoneshnikovo
# Processing Record 25 of Set 3 | wenling
# Processing Record 26 of Set 3 | kununurra
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | barentu
# Processing Record 29 of Set 3 | fortuna
# Processing Record 30 of Set 3 | kahului
# Processing Record 31 of Set 3 | cockburn town
# Processing Record 32 of Set 3 | baykit
# Processing Record 33 of Set 3 | riverton
# Processing Record 34 of Set 3 | nome
# Processing Record 35 of Set 3 | minot
# Processing Record 36 of Set 3 | zelhem
# Processing Record 37 of Set 3 | atuona
# Processing Record 38 of Set 3 | diego de almagro
# Processing Record 39 of Set 3 | lakes entrance
# Processing Record 40 of Set 3 | port augusta
# Processing Record 41 of Set 3 | yangcun
# Processing Record 42 of Set 3 | port alfred
# Processing Record 43 of Set 3 | bredasdorp
# Processing Record 44 of Set 3 | guerrero negro
# Processing Record 45 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 3 | esperance
# Processing Record 47 of Set 3 | cocobeach
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | legnica
# Processing Record 50 of Set 3 | opuwo
# Processing Record 1 of Set 4 | cape town
# Processing Record 2 of Set 4 | ostrovnoy
# Processing Record 3 of Set 4 | usman
# Processing Record 4 of Set 4 | severo-kurilsk
# Processing Record 5 of Set 4 | nicoya
# Processing Record 6 of Set 4 | danilovka
# Processing Record 7 of Set 4 | bengkulu
# Processing Record 8 of Set 4 | praia da vitoria
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | westport
# Processing Record 11 of Set 4 | odesskoye
# Processing Record 12 of Set 4 | san carlos de bariloche
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | bida
# Processing Record 15 of Set 4 | ballina
# Processing Record 16 of Set 4 | bayir
# Processing Record 17 of Set 4 | touros
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | yar-sale
# Processing Record 20 of Set 4 | torbay
# Processing Record 21 of Set 4 | hasaki
# Processing Record 22 of Set 4 | samandag
# Processing Record 23 of Set 4 | chuy
# Processing Record 24 of Set 4 | north bend
# Processing Record 25 of Set 4 | new norfolk
# Processing Record 26 of Set 4 | salalah
# Processing Record 27 of Set 4 | saint-philippe
# Processing Record 28 of Set 4 | lompoc
# Processing Record 29 of Set 4 | saldanha
# Processing Record 30 of Set 4 | faanui
# Processing Record 31 of Set 4 | preeceville
# Processing Record 32 of Set 4 | darhan
# Processing Record 33 of Set 4 | egvekinot
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | tomatlan
# Processing Record 36 of Set 4 | zhitikara
# City not found. Skipping...
# Processing Record 37 of Set 4 | nouadhibou
# Processing Record 38 of Set 4 | lerwick
# Processing Record 39 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 4 | cherskiy
# Processing Record 41 of Set 4 | asau
# Processing Record 42 of Set 4 | marsh harbour
# Processing Record 43 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 4 | marsa matruh
# Processing Record 45 of Set 4 | burns lake
# Processing Record 46 of Set 4 | progreso
# Processing Record 47 of Set 4 | lavrentiya
# Processing Record 48 of Set 4 | wukari
# Processing Record 49 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 4 | taoudenni
# Processing Record 1 of Set 5 | borlange
# City not found. Skipping...
# Processing Record 2 of Set 5 | qui nhon
# Processing Record 3 of Set 5 | barraute
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | quelimane
# Processing Record 6 of Set 5 | birin
# Processing Record 7 of Set 5 | uhlove
# Processing Record 8 of Set 5 | las palmas
# Processing Record 9 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 5 | yulara
# Processing Record 11 of Set 5 | coquimbo
# Processing Record 12 of Set 5 | saint-joseph
# Processing Record 13 of Set 5 | starosubkhangulovo
# Processing Record 14 of Set 5 | pangnirtung
# Processing Record 15 of Set 5 | copiapo
# Processing Record 16 of Set 5 | vestmannaeyjar
# Processing Record 17 of Set 5 | aden
# Processing Record 18 of Set 5 | kashi
# Processing Record 19 of Set 5 | teluknaga
# Processing Record 20 of Set 5 | berlevag
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | waipawa
# Processing Record 23 of Set 5 | susanville
# Processing Record 24 of Set 5 | konanur
# Processing Record 25 of Set 5 | sulangan
# Processing Record 26 of Set 5 | longkou
# Processing Record 27 of Set 5 | matay
# Processing Record 28 of Set 5 | orikum
# Processing Record 29 of Set 5 | cassia
# Processing Record 30 of Set 5 | aykhal
# Processing Record 31 of Set 5 | hithadhoo
# Processing Record 32 of Set 5 | lorengau
# Processing Record 33 of Set 5 | thompson
# Processing Record 34 of Set 5 | moissala
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 5 | santa barbara
# Processing Record 38 of Set 5 | hamilton
# Processing Record 39 of Set 5 | vao
# Processing Record 40 of Set 5 | fujin
# Processing Record 41 of Set 5 | kabalo
# Processing Record 42 of Set 5 | victoria
# Processing Record 43 of Set 5 | ilulissat
# Processing Record 44 of Set 5 | bac lieu
# Processing Record 45 of Set 5 | kimbe
# Processing Record 46 of Set 5 | mahebourg
# Processing Record 47 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 5 | dunedin
# Processing Record 49 of Set 5 | duz
# City not found. Skipping...
# Processing Record 50 of Set 5 | anadyr
# Processing Record 1 of Set 6 | bryan
# Processing Record 2 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 6 | lazaro cardenas
# Processing Record 4 of Set 6 | esplanada
# Processing Record 5 of Set 6 | port moresby
# Processing Record 6 of Set 6 | mitzic
# Processing Record 7 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 6 | te anau
# Processing Record 9 of Set 6 | hailar
# Processing Record 10 of Set 6 | tura
# Processing Record 11 of Set 6 | nara
# Processing Record 12 of Set 6 | shakawe
# Processing Record 13 of Set 6 | san patricio
# Processing Record 14 of Set 6 | nizhnevartovsk
# Processing Record 15 of Set 6 | camana
# Processing Record 16 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 6 | luwingu
# Processing Record 18 of Set 6 | maceio
# Processing Record 19 of Set 6 | hervey bay
# Processing Record 20 of Set 6 | phonhong
# Processing Record 21 of Set 6 | tolaga bay
# Processing Record 22 of Set 6 | leningradskiy
# Processing Record 23 of Set 6 | derzhavinsk
# Processing Record 24 of Set 6 | bohodukhiv
# Processing Record 25 of Set 6 | inuvik
# Processing Record 26 of Set 6 | northam
# Processing Record 27 of Set 6 | corrente
# Processing Record 28 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 6 | margate
# Processing Record 30 of Set 6 | the valley
# Processing Record 31 of Set 6 | portland
# Processing Record 32 of Set 6 | lufilufi
# Processing Record 33 of Set 6 | benguela
# Processing Record 34 of Set 6 | beruni
# City not found. Skipping...
# Processing Record 35 of Set 6 | urumqi
# Processing Record 36 of Set 6 | omboue
# Processing Record 37 of Set 6 | pevek
# Processing Record 38 of Set 6 | codajas
# Processing Record 39 of Set 6 | upington
# Processing Record 40 of Set 6 | muros
# Processing Record 41 of Set 6 | palmares do sul
# Processing Record 42 of Set 6 | cidreira
# Processing Record 43 of Set 6 | amarante do maranhao
# Processing Record 44 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 6 | agva
# City not found. Skipping...
# Processing Record 46 of Set 6 | singaparna
# Processing Record 47 of Set 6 | pisco
# Processing Record 48 of Set 6 | zhangye
# Processing Record 49 of Set 6 | yokadouma
# Processing Record 50 of Set 6 | krasnoselkup
# Processing Record 1 of Set 7 | grand gaube
# Processing Record 2 of Set 7 | hoddesdon
# Processing Record 3 of Set 7 | asyut
# Processing Record 4 of Set 7 | san quintin
# Processing Record 5 of Set 7 | dhidhdhoo
# Processing Record 6 of Set 7 | bonthe
# Processing Record 7 of Set 7 | tiarei
# Processing Record 8 of Set 7 | kazachinskoye
# Processing Record 9 of Set 7 | airai
# Processing Record 10 of Set 7 | jibuti
# Processing Record 11 of Set 7 | plakhtiyivka
# Processing Record 12 of Set 7 | aklavik
# Processing Record 13 of Set 7 | erenhot
# Processing Record 14 of Set 7 | bemidji
# Processing Record 15 of Set 7 | gat
# Processing Record 16 of Set 7 | parakou
# Processing Record 17 of Set 7 | valle nacional
# Processing Record 18 of Set 7 | naze
# Processing Record 19 of Set 7 | chai nat
# Processing Record 20 of Set 7 | prince rupert
# Processing Record 21 of Set 7 | riberalta
# Processing Record 22 of Set 7 | maniwaki
# Processing Record 23 of Set 7 | cheney
# Processing Record 24 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 7 | gamba
# Processing Record 26 of Set 7 | luanda
# Processing Record 27 of Set 7 | campbell river
# Processing Record 28 of Set 7 | palu
# Processing Record 29 of Set 7 | birao
# Processing Record 30 of Set 7 | panaba
# Processing Record 31 of Set 7 | balad
# Processing Record 32 of Set 7 | bani
# Processing Record 33 of Set 7 | karachi
# Processing Record 34 of Set 7 | ancud
# Processing Record 35 of Set 7 | olinda
# Processing Record 36 of Set 7 | nefteyugansk
# Processing Record 37 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 7 | isabela
# Processing Record 39 of Set 7 | baghdad
# Processing Record 40 of Set 7 | sao filipe
# Processing Record 41 of Set 7 | pathanamthitta
# Processing Record 42 of Set 7 | bilma
# Processing Record 43 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 44 of Set 7 | wajid
# Processing Record 45 of Set 7 | kopervik
# Processing Record 46 of Set 7 | kharp
# Processing Record 47 of Set 7 | okhotsk
# Processing Record 48 of Set 7 | minas
# Processing Record 49 of Set 7 | mackenzie
# Processing Record 50 of Set 7 | broome
# Processing Record 1 of Set 8 | marienburg
# Processing Record 2 of Set 8 | we
# City not found. Skipping...
# Processing Record 3 of Set 8 | kenai
# Processing Record 4 of Set 8 | codrington
# Processing Record 5 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 8 | pemangkat
# Processing Record 7 of Set 8 | manggar
# Processing Record 8 of Set 8 | yamethin
# Processing Record 9 of Set 8 | ambon
# Processing Record 10 of Set 8 | avera
# Processing Record 11 of Set 8 | aberdeen
# Processing Record 12 of Set 8 | tadine
# Processing Record 13 of Set 8 | saurimo
# Processing Record 14 of Set 8 | ayorou
# Processing Record 15 of Set 8 | fukue
# Processing Record 16 of Set 8 | talnakh
# Processing Record 17 of Set 8 | myitkyina
# Processing Record 18 of Set 8 | isangel
# Processing Record 19 of Set 8 | nyurba
# Processing Record 20 of Set 8 | berdigestyakh
# Processing Record 21 of Set 8 | longview
# Processing Record 22 of Set 8 | sao geraldo do araguaia
# Processing Record 23 of Set 8 | san carlos
# Processing Record 24 of Set 8 | yelizovo
# Processing Record 25 of Set 8 | guiratinga
# Processing Record 26 of Set 8 | ningan
# City not found. Skipping...
# Processing Record 27 of Set 8 | dingle
# Processing Record 28 of Set 8 | puerto del rosario
# Processing Record 29 of Set 8 | qaqortoq
# Processing Record 30 of Set 8 | mafeteng
# Processing Record 31 of Set 8 | srednekolymsk
# Processing Record 32 of Set 8 | arawa
# Processing Record 33 of Set 8 | amos
# Processing Record 34 of Set 8 | meulaboh
# Processing Record 35 of Set 8 | kamwenge
# Processing Record 36 of Set 8 | karpathos
# Processing Record 37 of Set 8 | laguna
# Processing Record 38 of Set 8 | sobolevo
# Processing Record 39 of Set 8 | kasempa
# Processing Record 40 of Set 8 | honningsvag
# Processing Record 41 of Set 8 | port hardy
# Processing Record 42 of Set 8 | merauke
# Processing Record 43 of Set 8 | east london
# Processing Record 44 of Set 8 | neijiang
# Processing Record 45 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 8 | sterling
# Processing Record 47 of Set 8 | buzdyak
# Processing Record 48 of Set 8 | souillac
# Processing Record 49 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 50 of Set 8 | ushtobe
# Processing Record 1 of Set 9 | dobrinka
# Processing Record 2 of Set 9 | liverpool
# Processing Record 3 of Set 9 | poum
# Processing Record 4 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 9 | nenjiang
# Processing Record 6 of Set 9 | ranong
# Processing Record 7 of Set 9 | voznesenye
# Processing Record 8 of Set 9 | sur
# Processing Record 9 of Set 9 | erzin
# Processing Record 10 of Set 9 | hof
# Processing Record 11 of Set 9 | takab
# Processing Record 12 of Set 9 | bukama
# Processing Record 13 of Set 9 | kaitangata
# Processing Record 14 of Set 9 | pokrovka
# Processing Record 15 of Set 9 | pontianak
# Processing Record 16 of Set 9 | beringovskiy
# Processing Record 17 of Set 9 | katherine
# Processing Record 18 of Set 9 | los llanos de aridane
# Processing Record 19 of Set 9 | tarnogskiy gorodok
# Processing Record 20 of Set 9 | vila franca do campo
# Processing Record 21 of Set 9 | katsuura
# Processing Record 22 of Set 9 | yarada
# Processing Record 23 of Set 9 | high level
# Processing Record 24 of Set 9 | kudahuvadhoo
# Processing Record 25 of Set 9 | xining
# Processing Record 26 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 9 | vila velha
# Processing Record 28 of Set 9 | ormara
# Processing Record 29 of Set 9 | ulladulla
# Processing Record 30 of Set 9 | port hawkesbury
# Processing Record 31 of Set 9 | fort madison
# Processing Record 32 of Set 9 | ust-maya
# Processing Record 33 of Set 9 | san luis
# Processing Record 34 of Set 9 | santa fe
# Processing Record 35 of Set 9 | goderich
# Processing Record 36 of Set 9 | korla
# Processing Record 37 of Set 9 | broken hill
# Processing Record 38 of Set 9 | dutlwe
# Processing Record 39 of Set 9 | barreiras
# Processing Record 40 of Set 9 | vardo
# Processing Record 41 of Set 9 | shimoda
# Processing Record 42 of Set 9 | la ronge
# Processing Record 43 of Set 9 | namibe
# Processing Record 44 of Set 9 | filadelfia
# Processing Record 45 of Set 9 | mwense
# Processing Record 46 of Set 9 | teluk intan
# Processing Record 47 of Set 9 | komsomolskiy
# Processing Record 48 of Set 9 | bjornevatn
# Processing Record 49 of Set 9 | lambarene
# Processing Record 50 of Set 9 | faya
# Processing Record 1 of Set 10 | silver city
# Processing Record 2 of Set 10 | shangzhi
# Processing Record 3 of Set 10 | potosi
# Processing Record 4 of Set 10 | rossosh
# Processing Record 5 of Set 10 | hofn
# Processing Record 6 of Set 10 | honiara
# Processing Record 7 of Set 10 | kavaratti
# Processing Record 8 of Set 10 | mbaiki
# Processing Record 9 of Set 10 | boyolangu
# Processing Record 10 of Set 10 | burnie
# Processing Record 11 of Set 10 | abu dhabi
# Processing Record 12 of Set 10 | mitchell
# Processing Record 13 of Set 10 | houma
# Processing Record 14 of Set 10 | ust-nera
# Processing Record 15 of Set 10 | wilkie
# Processing Record 16 of Set 10 | tornio
# Processing Record 17 of Set 10 | imeni morozova
# Processing Record 18 of Set 10 | matagami
# Processing Record 19 of Set 10 | yuanping
# Processing Record 20 of Set 10 | honggang
# Processing Record 21 of Set 10 | chegdomyn
# Processing Record 22 of Set 10 | sioux falls
# Processing Record 23 of Set 10 | vallenar
# Processing Record 24 of Set 10 | fare
# Processing Record 25 of Set 10 | barra do garcas
# Processing Record 26 of Set 10 | cao bang
# Processing Record 27 of Set 10 | mangochi
# Processing Record 28 of Set 10 | itapaci
# Processing Record 29 of Set 10 | damara
# Processing Record 30 of Set 10 | boden
# Processing Record 31 of Set 10 | puerto quijarro
# Processing Record 32 of Set 10 | tuxtepec
# Processing Record 33 of Set 10 | aksarka
# Processing Record 34 of Set 10 | saint-francois
# Processing Record 35 of Set 10 | hambantota
# Processing Record 36 of Set 10 | soure
# Processing Record 37 of Set 10 | pathein
# Processing Record 38 of Set 10 | teya
# Processing Record 39 of Set 10 | dabakala
# Processing Record 40 of Set 10 | coihaique
# Processing Record 41 of Set 10 | bundaberg
# Processing Record 42 of Set 10 | rundu
# Processing Record 43 of Set 10 | san juan
# Processing Record 44 of Set 10 | whitecourt
# Processing Record 45 of Set 10 | severnoye
# Processing Record 46 of Set 10 | mayo
# Processing Record 47 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 10 | beyneu
# Processing Record 49 of Set 10 | maubin
# Processing Record 50 of Set 10 | zambezi
# Processing Record 1 of Set 11 | pombia
# Processing Record 2 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 3 of Set 11 | hauterive
# Processing Record 4 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 5 of Set 11 | joao camara
# Processing Record 6 of Set 11 | aba
# Processing Record 7 of Set 11 | morehead
# Processing Record 8 of Set 11 | san javier
# Processing Record 9 of Set 11 | saint-louis
# Processing Record 10 of Set 11 | woodstock
# Processing Record 11 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 12 of Set 11 | mahibadhoo
# Processing Record 13 of Set 11 | sungaipenuh
# Processing Record 14 of Set 11 | port macquarie
# Processing Record 15 of Set 11 | klaksvik
# Processing Record 16 of Set 11 | charlestown
# Processing Record 17 of Set 11 | maku
# Processing Record 18 of Set 11 | russkaya polyana
# Processing Record 19 of Set 11 | severnyy
# Processing Record 20 of Set 11 | aksha
# Processing Record 21 of Set 11 | saravan
# Processing Record 22 of Set 11 | tabuk
# Processing Record 23 of Set 11 | ucluelet
# Processing Record 24 of Set 11 | bonoua
# Processing Record 25 of Set 11 | caloocan
# Processing Record 26 of Set 11 | pokhara
# Processing Record 27 of Set 11 | tonantins
# Processing Record 28 of Set 11 | amahai
# Processing Record 29 of Set 11 | mao
# Processing Record 30 of Set 11 | saint-pierre
# Processing Record 31 of Set 11 | adrar
# Processing Record 32 of Set 11 | luena
# Processing Record 33 of Set 11 | sola
# Processing Record 34 of Set 11 | constitucion
# Processing Record 35 of Set 11 | bubaque
# Processing Record 36 of Set 11 | fethiye
# Processing Record 37 of Set 11 | buala
# Processing Record 38 of Set 11 | chivilcoy
# Processing Record 39 of Set 11 | wufeng
# Processing Record 40 of Set 11 | camopi
# Processing Record 41 of Set 11 | coihueco
# Processing Record 42 of Set 11 | inongo
# Processing Record 43 of Set 11 | karymskoye
# Processing Record 44 of Set 11 | chambersburg
# Processing Record 45 of Set 11 | ucar
# Processing Record 46 of Set 11 | nichinan
# Processing Record 47 of Set 11 | batagay-alyta
# Processing Record 48 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 49 of Set 11 | nishihara
# Processing Record 50 of Set 11 | namtsy
# Processing Record 1 of Set 12 | synya
# Processing Record 2 of Set 12 | freeport
# Processing Record 3 of Set 12 | dali
# Processing Record 4 of Set 12 | san fernando
# Processing Record 5 of Set 12 | redlands
# Processing Record 6 of Set 12 | oussouye
# Processing Record 7 of Set 12 | energeticheskiy
# Processing Record 8 of Set 12 | loanda
# Processing Record 9 of Set 12 | ponta pora
# Processing Record 10 of Set 12 | mikhaylovka
# Processing Record 11 of Set 12 | banda aceh
# Processing Record 12 of Set 12 | tokmak
# Processing Record 13 of Set 12 | palana
# Processing Record 14 of Set 12 | candido mendes
# Processing Record 15 of Set 12 | byron bay
# Processing Record 16 of Set 12 | sitamau
# Processing Record 17 of Set 12 | puerto escondido
# Processing Record 18 of Set 12 | chany
# Processing Record 19 of Set 12 | tezu
# Processing Record 20 of Set 12 | grimshaw
# Processing Record 21 of Set 12 | saint-augustin
# Processing Record 22 of Set 12 | healesville
# Processing Record 23 of Set 12 | mugur-aksy
# Processing Record 24 of Set 12 | lac du bonnet
# Processing Record 25 of Set 12 | bontang
# Processing Record 26 of Set 12 | vitim
# Processing Record 27 of Set 12 | jiangyou
# Processing Record 28 of Set 12 | ugoofaaru
# Processing Record 29 of Set 12 | mabaruma
# Processing Record 30 of Set 12 | yaroslavskiy
# Processing Record 31 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 32 of Set 12 | sao jose da coroa grande
# Processing Record 33 of Set 12 | columbus
# Processing Record 34 of Set 12 | guye
# Processing Record 35 of Set 12 | guanica
# Processing Record 36 of Set 12 | juneau
# Processing Record 37 of Set 12 | vanavara
# Processing Record 38 of Set 12 | qasigiannguit
# Processing Record 39 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 12 | rudbar
# Processing Record 41 of Set 12 | manoel urbano
# Processing Record 42 of Set 12 | kasongo-lunda
# Processing Record 43 of Set 12 | sinnamary
# Processing Record 44 of Set 12 | tukrah
# Processing Record 45 of Set 12 | nakusp
# Processing Record 46 of Set 12 | wynyard
# Processing Record 47 of Set 12 | north platte
# Processing Record 48 of Set 12 | revda
# Processing Record 49 of Set 12 | smolenka
# Processing Record 50 of Set 12 | yinchuan
# Processing Record 1 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 2 of Set 13 | guliston
# Processing Record 3 of Set 13 | store heddinge
# Processing Record 4 of Set 13 | saint anthony
# Processing Record 5 of Set 13 | matao
# Processing Record 6 of Set 13 | mesyagutovo
# Processing Record 7 of Set 13 | ketchikan
# Processing Record 8 of Set 13 | madhupur
# Processing Record 9 of Set 13 | oranjemund
# Processing Record 10 of Set 13 | sept-iles
# Processing Record 11 of Set 13 | rawson
# Processing Record 12 of Set 13 | padang
# Processing Record 13 of Set 13 | haines junction
# Processing Record 14 of Set 13 | mombaca
# Processing Record 15 of Set 13 | jishou
# Processing Record 16 of Set 13 | ponta delgada
# Processing Record 17 of Set 13 | jinchang
# Processing Record 18 of Set 13 | ozernovskiy
# Processing Record 19 of Set 13 | roald
# Processing Record 20 of Set 13 | erdenet
# Processing Record 21 of Set 13 | alma
# Processing Record 22 of Set 13 | buraydah
# Processing Record 23 of Set 13 | thinadhoo
# Processing Record 24 of Set 13 | alofi
# Processing Record 25 of Set 13 | alekseyevsk
# Processing Record 26 of Set 13 | peleduy
# Processing Record 27 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 28 of Set 13 | fenoarivo atsinanana
# Processing Record 29 of Set 13 | jesup
# Processing Record 30 of Set 13 | formosa
# Processing Record 31 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 13 | angoche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kapaa  22.0752 -159.3190     70.20        87         100
# 1         Rikitea -23.1203 -134.9692     74.55        82         100
# 2         Cayenne   4.9333  -52.3333     77.04        88           0
# 3          Albany  42.6001  -73.9662     49.73        54         100
# 4           Vaini -21.2000 -175.2000     78.96        83          75
# 5    Puerto Ayora  -0.7393  -90.3518     76.96        89          68
# 6        Bloemhof -27.6469   25.6070     77.68        18          12
# 7    Saint George  37.1041 -113.5841     57.43        28           0
# 8  Ribeira Grande  38.5167  -28.7000     63.00        59          40
# 9        Lillooet  50.6856 -121.9420     48.65        78          45
#
#    Wind Speed Country                 Date
# 0       29.93      US  2022-11-24 19:51:22
# 1       10.38      PF  2022-11-24 19:51:22
# 2        0.00      GF  2022-11-24 19:51:23
# 3        1.01      US  2022-11-24 19:51:23
# 4        5.75      TO  2022-11-24 19:51:24
# 5        5.01      EC  2022-11-24 19:51:24
# 6       12.35      ZA  2022-11-24 19:51:25
# 7        5.75      US  2022-11-24 19:51:25
# 8       14.00      PT  2022-11-24 19:48:01
# 9        3.31      CA  2022-11-24 19:51:26

# %%
#6.2.7

# %%
#Create an array with the order of the columns we want in the output 
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
#Create a new data frame with the new column order and display
newcity_data_file = city_data_df[new_column_order]
newcity_data_file.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0           Kapaa      US  2022-11-24 19:51:22  22.0752 -159.3190     70.20
# 1         Rikitea      PF  2022-11-24 19:51:22 -23.1203 -134.9692     74.55
# 2         Cayenne      GF  2022-11-24 19:51:23   4.9333  -52.3333     77.04
# 3          Albany      US  2022-11-24 19:51:23  42.6001  -73.9662     49.73
# 4           Vaini      TO  2022-11-24 19:51:24 -21.2000 -175.2000     78.96
# 5    Puerto Ayora      EC  2022-11-24 19:51:24  -0.7393  -90.3518     76.96
# 6        Bloemhof      ZA  2022-11-24 19:51:25 -27.6469   25.6070     77.68
# 7    Saint George      US  2022-11-24 19:51:25  37.1041 -113.5841     57.43
# 8  Ribeira Grande      PT  2022-11-24 19:48:01  38.5167  -28.7000     63.00
# 9        Lillooet      CA  2022-11-24 19:51:26  50.6856 -121.9420     48.65
#
#    Humidity  Cloudiness  Wind Speed
# 0        87         100       29.93
# 1        82         100       10.38
# 2        88           0        0.00
# 3        54         100        1.01
# 4        83          75        5.75
# 5        89          68        5.01
# 6        18          12       12.35
# 7        28           0        5.75
# 8        59          40       14.00
# 9        78          45        3.31

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
newcity_data_file.to_csv(output_data_file, index_label="City_ID")
