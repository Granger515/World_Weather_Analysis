# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import random
#from citipy import citipy
#import json

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 714

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

import sys
sys.path.append('../')

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1f11fd4c1124fe0f9effb3158e013dd4

# %%
# Import the datetime module from the datetime library
from datetime import datetime

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(65)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1
    
    try:
    
        # Run an API request for each of the cities
        city_weather = requests.get(city_url).json()
    
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Current Description": city_description})

    except Exception as e:
        print("city not found..skipping...")
        import traceback
        print(traceback.format_exc())
        pass


print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | watsa
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | kushiro
# Processing Record 5 of Set 1 | belushya guba
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 6 of Set 1 | tsihombe
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 7 of Set 1 | amderma
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | togul
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | micheweni
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | alice springs
# Processing Record 16 of Set 1 | inveraray
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 17 of Set 1 | chabahar
# Processing Record 18 of Set 1 | chuy
# Processing Record 19 of Set 1 | ahome
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | kiruna
# Processing Record 22 of Set 1 | ndago
# Processing Record 23 of Set 1 | sao felix do xingu
# Processing Record 24 of Set 1 | severo-yeniseyskiy
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | ixtapa
# Processing Record 27 of Set 1 | maragogi
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | victoria
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | la fria
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | severo-kurilsk
# Processing Record 35 of Set 1 | taolanaro
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 36 of Set 1 | la ronge
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | wahiawa
# Processing Record 39 of Set 1 | innisfail
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | urdzhar
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 42 of Set 1 | lebanon
# Processing Record 43 of Set 1 | haines junction
# Processing Record 44 of Set 1 | kargasok
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | cidreira
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | miramar
# Processing Record 2 of Set 2 | sao joao da barra
# Processing Record 3 of Set 2 | vanimo
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | cortez
# Processing Record 9 of Set 2 | rochester
# Processing Record 10 of Set 2 | chara
# Processing Record 11 of Set 2 | mulchen
# Processing Record 12 of Set 2 | chapais
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | westport
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | barentsburg
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 20 of Set 2 | henties bay
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | torbay
# Processing Record 23 of Set 2 | bathsheba
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | whitecourt
# Processing Record 27 of Set 2 | vila franca do campo
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | mys shmidta
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 30 of Set 2 | velyka bahachka
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | nome
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | bukachacha
# Processing Record 35 of Set 2 | lavrentiya
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | tazovskiy
# Processing Record 38 of Set 2 | naze
# Processing Record 39 of Set 2 | tromso
# Processing Record 40 of Set 2 | sentyabrskiy
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 41 of Set 2 | biloela
# Processing Record 42 of Set 2 | tripoli
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | mandera
# Processing Record 45 of Set 2 | cherskiy
# Processing Record 46 of Set 2 | ahipara
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | kaitangata
# Processing Record 49 of Set 2 | samusu
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 50 of Set 2 | luderitz
# Processing Record 1 of Set 3 | quelimane
# Processing Record 2 of Set 3 | birao
# Processing Record 3 of Set 3 | port hardy
# Processing Record 4 of Set 3 | fortuna
# Processing Record 5 of Set 3 | dingle
# Processing Record 6 of Set 3 | nizhniy baskunchak
# Processing Record 7 of Set 3 | potsdam
# Processing Record 8 of Set 3 | sao filipe
# Processing Record 9 of Set 3 | pisco
# Processing Record 10 of Set 3 | jamestown
# Processing Record 11 of Set 3 | soe
# Processing Record 12 of Set 3 | lagoa
# Processing Record 13 of Set 3 | alice
# Processing Record 14 of Set 3 | tsagan aman
# Processing Record 15 of Set 3 | wolnzach
# Processing Record 16 of Set 3 | vaitupu
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 17 of Set 3 | itoman
# Processing Record 18 of Set 3 | avarua
# Processing Record 19 of Set 3 | atar
# Processing Record 20 of Set 3 | yoichi
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | attawapiskat
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | tuatapere
# Processing Record 25 of Set 3 | barrow
# Processing Record 26 of Set 3 | sinnamary
# Processing Record 27 of Set 3 | mangile
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 28 of Set 3 | erzin
# Processing Record 29 of Set 3 | santa rosa
# Processing Record 30 of Set 3 | the valley
# Processing Record 31 of Set 3 | mount isa
# Processing Record 32 of Set 3 | college
# Processing Record 33 of Set 3 | roald
# Processing Record 34 of Set 3 | sambava
# Processing Record 35 of Set 3 | batagay
# Processing Record 36 of Set 3 | kuusamo
# Processing Record 37 of Set 3 | mopti
# Processing Record 38 of Set 3 | kruisfontein
# Processing Record 39 of Set 3 | hithadhoo
# Processing Record 40 of Set 3 | beira
# Processing Record 41 of Set 3 | yumen
# Processing Record 42 of Set 3 | kattivakkam
# Processing Record 43 of Set 3 | marsaxlokk
# Processing Record 44 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 3 | bubaque
# Processing Record 46 of Set 3 | rehnan
# Processing Record 47 of Set 3 | nelson bay
# Processing Record 48 of Set 3 | hihifo
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 49 of Set 3 | dwarka
# Processing Record 50 of Set 3 | shkoder
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | codrington
# Processing Record 3 of Set 4 | wilmington
# Processing Record 4 of Set 4 | havre-saint-pierre
# Processing Record 5 of Set 4 | sitka
# Processing Record 6 of Set 4 | prince rupert
# Processing Record 7 of Set 4 | haimen
# Processing Record 8 of Set 4 | port-cartier
# Processing Record 9 of Set 4 | nanortalik
# Processing Record 10 of Set 4 | geraldton
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | palabuhanratu
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 13 of Set 4 | bandarbeyla
# Processing Record 14 of Set 4 | taburi
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 15 of Set 4 | denia
# Processing Record 16 of Set 4 | tiksi
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | lompoc
# Processing Record 19 of Set 4 | mayo
# Processing Record 20 of Set 4 | chokurdakh
# Processing Record 21 of Set 4 | kampong thum
# Processing Record 22 of Set 4 | zhigansk
# Processing Record 23 of Set 4 | casa nova
# Processing Record 24 of Set 4 | dayong
# Processing Record 25 of Set 4 | havoysund
# Processing Record 26 of Set 4 | hauterive
# Processing Record 27 of Set 4 | selfoss
# Processing Record 28 of Set 4 | miri
# Processing Record 29 of Set 4 | hokitika
# Processing Record 30 of Set 4 | lazaro cardenas
# Processing Record 31 of Set 4 | morros
# Processing Record 32 of Set 4 | port elizabeth
# Processing Record 33 of Set 4 | hami
# Processing Record 34 of Set 4 | gunnedah
# Processing Record 35 of Set 4 | alihe
# Processing Record 36 of Set 4 | goba
# Processing Record 37 of Set 4 | bud
# Processing Record 38 of Set 4 | mount gambier
# Processing Record 39 of Set 4 | vengurla
# Processing Record 40 of Set 4 | pangnirtung
# Processing Record 41 of Set 4 | teya
# Processing Record 42 of Set 4 | dhankuta
# Processing Record 43 of Set 4 | wagga wagga
# Processing Record 44 of Set 4 | khor
# Processing Record 45 of Set 4 | honiara
# Processing Record 46 of Set 4 | san matias
# Processing Record 47 of Set 4 | narsaq
# Processing Record 48 of Set 4 | pokhara
# Processing Record 49 of Set 4 | otradnoye
# Processing Record 50 of Set 4 | nouakchott
# Processing Record 1 of Set 5 | shenjiamen
# Processing Record 2 of Set 5 | ostrovnoy
# Processing Record 3 of Set 5 | gornopravdinsk
# Processing Record 4 of Set 5 | barreirinha
# Processing Record 5 of Set 5 | karaul
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 6 of Set 5 | udachnyy
# Processing Record 7 of Set 5 | aksha
# Processing Record 8 of Set 5 | prieska
# Processing Record 9 of Set 5 | yaqui
# Processing Record 10 of Set 5 | mackay
# Processing Record 11 of Set 5 | bosaso
# Processing Record 12 of Set 5 | labuhan
# Processing Record 13 of Set 5 | haverfordwest
# Processing Record 14 of Set 5 | bilibino
# Processing Record 15 of Set 5 | kota
# Processing Record 16 of Set 5 | sinkat
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 17 of Set 5 | dali
# Processing Record 18 of Set 5 | arraial do cabo
# Processing Record 19 of Set 5 | el tarra
# Processing Record 20 of Set 5 | deputatskiy
# Processing Record 21 of Set 5 | brae
# Processing Record 22 of Set 5 | warqla
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 23 of Set 5 | antalaha
# Processing Record 24 of Set 5 | high level
# Processing Record 25 of Set 5 | san luis
# Processing Record 26 of Set 5 | vostok
# Processing Record 27 of Set 5 | vicuna
# Processing Record 28 of Set 5 | koumac
# Processing Record 29 of Set 5 | grants
# Processing Record 30 of Set 5 | turayf
# Processing Record 31 of Set 5 | stoyba
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 32 of Set 5 | meulaboh
# Processing Record 33 of Set 5 | nizhneyansk
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 34 of Set 5 | port lincoln
# Processing Record 35 of Set 5 | eagle pass
# Processing Record 36 of Set 5 | mikhaylovka
# Processing Record 37 of Set 5 | rawson
# Processing Record 38 of Set 5 | hamilton
# Processing Record 39 of Set 5 | fuxin
# Processing Record 40 of Set 5 | murgab
# Processing Record 41 of Set 5 | souillac
# Processing Record 42 of Set 5 | umzimvubu
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 43 of Set 5 | carnarvon
# Processing Record 44 of Set 5 | sucha beskidzka
# Processing Record 45 of Set 5 | saleaula
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 46 of Set 5 | vestmannaeyjar
# Processing Record 47 of Set 5 | knysna
# Processing Record 48 of Set 5 | lebu
# Processing Record 49 of Set 5 | xadani
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 50 of Set 5 | grand river south east
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 1 of Set 6 | aklavik
# Processing Record 2 of Set 6 | cabo san lucas
# Processing Record 3 of Set 6 | bozdar
# Processing Record 4 of Set 6 | kondinskoye
# Processing Record 5 of Set 6 | ishigaki
# Processing Record 6 of Set 6 | faanui
# Processing Record 7 of Set 6 | neuquen
# Processing Record 8 of Set 6 | mucurapo
# Processing Record 9 of Set 6 | clifton
# Processing Record 10 of Set 6 | alindao
# Processing Record 11 of Set 6 | pevek
# Processing Record 12 of Set 6 | dzaoudzi
# Processing Record 13 of Set 6 | alta floresta
# Processing Record 14 of Set 6 | gorin
# Processing Record 15 of Set 6 | lecce
# Processing Record 16 of Set 6 | karratha
# Processing Record 17 of Set 6 | zabid
# Processing Record 18 of Set 6 | nouadhibou
# Processing Record 19 of Set 6 | dongobesh
# Processing Record 20 of Set 6 | yeppoon
# Processing Record 21 of Set 6 | dalbandin
# Processing Record 22 of Set 6 | adrar
# Processing Record 23 of Set 6 | camana
# Processing Record 24 of Set 6 | alexandria
# Processing Record 25 of Set 6 | puerto leguizamo
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | hope
# Processing Record 28 of Set 6 | illoqqortoormiut
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 29 of Set 6 | formoso do araguaia
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 30 of Set 6 | taoudenni
# Processing Record 31 of Set 6 | aykhal
# Processing Record 32 of Set 6 | kirakira
# Processing Record 33 of Set 6 | skalistyy
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 34 of Set 6 | nantucket
# Processing Record 35 of Set 6 | kavaratti
# Processing Record 36 of Set 6 | tasbuget
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 37 of Set 6 | sao miguel do araguaia
# Processing Record 38 of Set 6 | flinders
# Processing Record 39 of Set 6 | tura
# Processing Record 40 of Set 6 | ancud
# Processing Record 41 of Set 6 | calama
# Processing Record 42 of Set 6 | burnie
# Processing Record 43 of Set 6 | mount hagen
# Processing Record 44 of Set 6 | pitimbu
# Processing Record 45 of Set 6 | babanusah
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 46 of Set 6 | tumannyy
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 47 of Set 6 | andarab
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 48 of Set 6 | seminole
# Processing Record 49 of Set 6 | pouebo
# Processing Record 50 of Set 6 | payo
# Processing Record 1 of Set 7 | christchurch
# Processing Record 2 of Set 7 | maebaru
# Processing Record 3 of Set 7 | yarmouth
# Processing Record 4 of Set 7 | baculin
# Processing Record 5 of Set 7 | luau
# Processing Record 6 of Set 7 | moose factory
# Processing Record 7 of Set 7 | mehamn
# Processing Record 8 of Set 7 | muroto
# Processing Record 9 of Set 7 | japura
# Processing Record 10 of Set 7 | sale
# Processing Record 11 of Set 7 | kitimat
# Processing Record 12 of Set 7 | chupa
# Processing Record 13 of Set 7 | longyearbyen
# Processing Record 14 of Set 7 | clyde river
# Processing Record 15 of Set 7 | seoul
# Processing Record 16 of Set 7 | lincolnton
# Processing Record 17 of Set 7 | emba
# Processing Record 18 of Set 7 | sabha
# Processing Record 19 of Set 7 | northam
# Processing Record 20 of Set 7 | aksu
# Processing Record 21 of Set 7 | samarai
# Processing Record 22 of Set 7 | san cristobal
# Processing Record 23 of Set 7 | armacao dos buzios
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 24 of Set 7 | bheramara
# Processing Record 25 of Set 7 | pemba
# Processing Record 26 of Set 7 | nadym
# Processing Record 27 of Set 7 | altay
# Processing Record 28 of Set 7 | yirol
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 29 of Set 7 | saint-georges
# Processing Record 30 of Set 7 | kargil
# Processing Record 31 of Set 7 | batsfjord
# Processing Record 32 of Set 7 | veisiejai
# Processing Record 33 of Set 7 | cairns
# Processing Record 34 of Set 7 | kalmunai
# Processing Record 35 of Set 7 | tilichiki
# Processing Record 36 of Set 7 | marcona
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 37 of Set 7 | jacareacanga
# Processing Record 38 of Set 7 | santiago de chuco
# Processing Record 39 of Set 7 | gouyave
# Processing Record 40 of Set 7 | chunskiy
# Processing Record 41 of Set 7 | verkhoyansk
# Processing Record 42 of Set 7 | kharp
# Processing Record 43 of Set 7 | eureka
# Processing Record 44 of Set 7 | nguru
# Processing Record 45 of Set 7 | merke
# Processing Record 46 of Set 7 | tasiilaq
# Processing Record 47 of Set 7 | salekhard
# Processing Record 48 of Set 7 | wahpeton
# Processing Record 49 of Set 7 | valparaiso
# Processing Record 50 of Set 7 | lorengau
# Processing Record 1 of Set 8 | quirinopolis
# Processing Record 2 of Set 8 | saint anthony
# Processing Record 3 of Set 8 | tuggurt
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 4 of Set 8 | raisio
# Processing Record 5 of Set 8 | sumbe
# Processing Record 6 of Set 8 | shimoda
# Processing Record 7 of Set 8 | fuengirola
# Processing Record 8 of Set 8 | tessalit
# Processing Record 9 of Set 8 | muzhi
# Processing Record 10 of Set 8 | kavieng
# Processing Record 11 of Set 8 | arlit
# Processing Record 12 of Set 8 | san rafael del sur
# Processing Record 13 of Set 8 | narasannapeta
# Processing Record 14 of Set 8 | lima duarte
# Processing Record 15 of Set 8 | leningradskiy
# Processing Record 16 of Set 8 | slave lake
# Processing Record 17 of Set 8 | kuching
# Processing Record 18 of Set 8 | cayenne
# Processing Record 19 of Set 8 | lokken verk
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 20 of Set 8 | huilong
# Processing Record 21 of Set 8 | salalah
# Processing Record 22 of Set 8 | tamworth
# Processing Record 23 of Set 8 | lins
# Processing Record 24 of Set 8 | riyadh
# Processing Record 25 of Set 8 | kawalu
# Processing Record 26 of Set 8 | irondequoit
# Processing Record 27 of Set 8 | abonnema
# Processing Record 28 of Set 8 | kodinsk
# Processing Record 29 of Set 8 | limoux
# Processing Record 30 of Set 8 | lufilufi
# Processing Record 31 of Set 8 | liaozhong
# Processing Record 32 of Set 8 | qui nhon
# Processing Record 33 of Set 8 | katsuura
# Processing Record 34 of Set 8 | ruza
# Processing Record 35 of Set 8 | alofi
# Processing Record 36 of Set 8 | baoqing
# Processing Record 37 of Set 8 | mahebourg
# Processing Record 38 of Set 8 | krasnoselkup
# Processing Record 39 of Set 8 | itaituba
# Processing Record 40 of Set 8 | caraballeda
# Processing Record 41 of Set 8 | kenai
# Processing Record 42 of Set 8 | kangaatsiaq
# Processing Record 43 of Set 8 | martil
# Processing Record 44 of Set 8 | praia da vitoria
# Processing Record 45 of Set 8 | garmsar
# Processing Record 46 of Set 8 | klaksvik
# Processing Record 47 of Set 8 | guerrero negro
# Processing Record 48 of Set 8 | ilulissat
# Processing Record 49 of Set 8 | kostivere
# Processing Record 50 of Set 8 | margate
# Processing Record 1 of Set 9 | arman
# Processing Record 2 of Set 9 | leon
# Processing Record 3 of Set 9 | blonduos
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 4 of Set 9 | tharad
# Processing Record 5 of Set 9 | teguise
# Processing Record 6 of Set 9 | krasnyy tekstilshchik
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 7 of Set 9 | norman wells
# Processing Record 8 of Set 9 | xai-xai
# Processing Record 9 of Set 9 | barcelos
# Processing Record 10 of Set 9 | turukhansk
# Processing Record 11 of Set 9 | kampot
# Processing Record 12 of Set 9 | nagato
# Processing Record 13 of Set 9 | vardo
# Processing Record 14 of Set 9 | salto de agua
# Processing Record 15 of Set 9 | horki
# Processing Record 16 of Set 9 | jumla
# Processing Record 17 of Set 9 | dalby
# Processing Record 18 of Set 9 | aflu
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 19 of Set 9 | gwanda
# Processing Record 20 of Set 9 | vao
# Processing Record 21 of Set 9 | pombas
# Processing Record 22 of Set 9 | olinda
# Processing Record 23 of Set 9 | coxim
# Processing Record 24 of Set 9 | los llanos de aridane
# Processing Record 25 of Set 9 | pozo colorado
# Processing Record 26 of Set 9 | siirt
# Processing Record 27 of Set 9 | xining
# Processing Record 28 of Set 9 | mogadishu
# Processing Record 29 of Set 9 | vangaindrano
# Processing Record 30 of Set 9 | tsaratanana
# Processing Record 31 of Set 9 | dormidontovka
# Processing Record 32 of Set 9 | husavik
# Processing Record 33 of Set 9 | rawlins
# Processing Record 34 of Set 9 | touros
# Processing Record 35 of Set 9 | simao
# Processing Record 36 of Set 9 | beloha
# Processing Record 37 of Set 9 | svoge
# Processing Record 38 of Set 9 | okhotsk
# Processing Record 39 of Set 9 | santa monica
# Processing Record 40 of Set 9 | ucluelet
# Processing Record 41 of Set 9 | kenitra
# Processing Record 42 of Set 9 | monrovia
# Processing Record 43 of Set 9 | namatanai
# Processing Record 44 of Set 9 | anadyr
# Processing Record 45 of Set 9 | manggar
# Processing Record 46 of Set 9 | kamaishi
# Processing Record 47 of Set 9 | pobe
# Processing Record 48 of Set 9 | asau
# Processing Record 49 of Set 9 | andselv
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 50 of Set 9 | chicama
# Processing Record 1 of Set 10 | zhitikara
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 2 of Set 10 | aitape
# Processing Record 3 of Set 10 | lom sak
# Processing Record 4 of Set 10 | port keats
# Processing Record 5 of Set 10 | ajaccio
# Processing Record 6 of Set 10 | sembakung
# Processing Record 7 of Set 10 | anloga
# Processing Record 8 of Set 10 | acapulco
# Processing Record 9 of Set 10 | dourbali
# Processing Record 10 of Set 10 | fairbanks
# Processing Record 11 of Set 10 | awbari
# Processing Record 12 of Set 10 | tambovka
# Processing Record 13 of Set 10 | kutum
# Processing Record 14 of Set 10 | sur
# Processing Record 15 of Set 10 | horsham
# Processing Record 16 of Set 10 | ust-maya
# Processing Record 17 of Set 10 | jiwani
# Processing Record 18 of Set 10 | maniitsoq
# Processing Record 19 of Set 10 | tonk
# Processing Record 20 of Set 10 | raozan
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 21 of Set 10 | vila velha
# Processing Record 22 of Set 10 | san quintin
# Processing Record 23 of Set 10 | umm lajj
# Processing Record 24 of Set 10 | madison
# Processing Record 25 of Set 10 | baykit
# Processing Record 26 of Set 10 | agirish
# Processing Record 27 of Set 10 | lewistown
# Processing Record 28 of Set 10 | saint-michel-des-saints
# Processing Record 29 of Set 10 | lethem
# Processing Record 30 of Set 10 | waunakee
# Processing Record 31 of Set 10 | pangody
# Processing Record 32 of Set 10 | shelburne
# Processing Record 33 of Set 10 | olds
# Processing Record 34 of Set 10 | senneterre
# Processing Record 35 of Set 10 | thinadhoo
# Processing Record 36 of Set 10 | yar-sale
# Processing Record 37 of Set 10 | tanout
# Processing Record 38 of Set 10 | kaeo
# Processing Record 39 of Set 10 | muros
# Processing Record 40 of Set 10 | saint-augustin
# Processing Record 41 of Set 10 | provideniya
# Processing Record 42 of Set 10 | jerome
# Processing Record 43 of Set 10 | gallup
# Processing Record 44 of Set 10 | hobyo
# Processing Record 45 of Set 10 | mkushi
# Processing Record 46 of Set 10 | redlands
# Processing Record 47 of Set 10 | sabang
# Processing Record 48 of Set 10 | nokaneng
# Processing Record 49 of Set 10 | camacha
# Processing Record 50 of Set 10 | manzhouli
# Processing Record 1 of Set 11 | mnogovershinnyy
# Processing Record 2 of Set 11 | caravelas
# Processing Record 3 of Set 11 | san juan
# Processing Record 4 of Set 11 | aswan
# Processing Record 5 of Set 11 | louisbourg
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 6 of Set 11 | dalvik
# Processing Record 7 of Set 11 | yulara
# Processing Record 8 of Set 11 | thiruvananthapuram
# Processing Record 9 of Set 11 | coquimbo
# Processing Record 10 of Set 11 | nishihara
# Processing Record 11 of Set 11 | turje
# Processing Record 12 of Set 11 | ilam
# Processing Record 13 of Set 11 | copiapo
# Processing Record 14 of Set 11 | viedma
# Processing Record 15 of Set 11 | ridgecrest
# Processing Record 16 of Set 11 | markapur
# Processing Record 17 of Set 11 | tabuk
# Processing Record 18 of Set 11 | bogatyr
# Processing Record 19 of Set 11 | slawno
# Processing Record 20 of Set 11 | san patricio
# Processing Record 21 of Set 11 | corralillo
# Processing Record 22 of Set 11 | portland
# Processing Record 23 of Set 11 | isla mujeres
# Processing Record 24 of Set 11 | jinji
# Processing Record 25 of Set 11 | hue
# Processing Record 26 of Set 11 | tual
# Processing Record 27 of Set 11 | paamiut
# Processing Record 28 of Set 11 | whyalla
# Processing Record 29 of Set 11 | hengshan
# Processing Record 30 of Set 11 | tuapse
# Processing Record 31 of Set 11 | stralsund
# Processing Record 32 of Set 11 | iqaluit
# Processing Record 33 of Set 11 | najran
# Processing Record 34 of Set 11 | kaputa
# Processing Record 35 of Set 11 | wakkanai
# Processing Record 36 of Set 11 | price
# Processing Record 37 of Set 11 | depok
# Processing Record 38 of Set 11 | koltsovo
# Processing Record 39 of Set 11 | itu
# Processing Record 40 of Set 11 | juifang
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 41 of Set 11 | meyungs
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 42 of Set 11 | broken hill
# Processing Record 43 of Set 11 | say
# Processing Record 44 of Set 11 | karauzyak
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 45 of Set 11 | nushki
# Processing Record 46 of Set 11 | pilao arcado
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 47 of Set 11 | puerto colombia
# Processing Record 48 of Set 11 | bolshegrivskoye
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 49 of Set 11 | tonstad
# Processing Record 50 of Set 11 | antofagasta
# Processing Record 1 of Set 12 | avera
# Processing Record 2 of Set 12 | hofn
# Processing Record 3 of Set 12 | poum
# Processing Record 4 of Set 12 | bengkulu
# Processing Record 5 of Set 12 | port macquarie
# Processing Record 6 of Set 12 | matagami
# Processing Record 7 of Set 12 | calhoun
# Processing Record 8 of Set 12 | alad
# Processing Record 9 of Set 12 | buala
# Processing Record 10 of Set 12 | port-gentil
# Processing Record 11 of Set 12 | nyimba
# Processing Record 12 of Set 12 | grindavik
# Processing Record 13 of Set 12 | buchanan
# Processing Record 14 of Set 12 | palauig
# Processing Record 15 of Set 12 | kazanskoye
# Processing Record 16 of Set 12 | verdalsora
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 17 of Set 12 | pemangkat
# Processing Record 18 of Set 12 | inhambane
# Processing Record 19 of Set 12 | yaan
# Processing Record 20 of Set 12 | zhangjiakou
# Processing Record 21 of Set 12 | vilyuysk
# Processing Record 22 of Set 12 | sioux lookout
# Processing Record 23 of Set 12 | sisimiut
# Processing Record 24 of Set 12 | marawi
# Processing Record 25 of Set 12 | segezha
# Processing Record 26 of Set 12 | tabou
# Processing Record 27 of Set 12 | tateyama
# Processing Record 28 of Set 12 | sulayman
# Processing Record 29 of Set 12 | ngukurr
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 30 of Set 12 | ozgon
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 31 of Set 12 | malartic
# Processing Record 32 of Set 12 | nador
# Processing Record 33 of Set 12 | ibra
# Processing Record 34 of Set 12 | eregli
# Processing Record 35 of Set 12 | willowmore
# Processing Record 36 of Set 12 | carutapera
# Processing Record 37 of Set 12 | quchan
# Processing Record 38 of Set 12 | egvekinot
# Processing Record 39 of Set 12 | belmonte
# Processing Record 40 of Set 12 | solwezi
# Processing Record 41 of Set 12 | tautira
# Processing Record 42 of Set 12 | neiafu
# Processing Record 43 of Set 12 | vallecillo
# Processing Record 44 of Set 12 | tolmachevo
# Processing Record 45 of Set 12 | flin flon
# Processing Record 46 of Set 12 | manacapuru
# Processing Record 47 of Set 12 | san carlos de bariloche
# Processing Record 48 of Set 12 | road town
# Processing Record 49 of Set 12 | bargal
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 50 of Set 12 | abu jubayhah
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 1 of Set 13 | half moon bay
# Processing Record 2 of Set 13 | arenillas
# Processing Record 3 of Set 13 | marquette
# Processing Record 4 of Set 13 | oktyabrskoye
# Processing Record 5 of Set 13 | lima
# Processing Record 6 of Set 13 | manta
# Processing Record 7 of Set 13 | mastic beach
# Processing Record 8 of Set 13 | sterling
# Processing Record 9 of Set 13 | jijiga
# Processing Record 10 of Set 13 | sobolevo
# Processing Record 11 of Set 13 | kapoeta
# Processing Record 12 of Set 13 | gobabis
# Processing Record 13 of Set 13 | serenje
# Processing Record 14 of Set 13 | vilcun
# Processing Record 15 of Set 13 | comodoro rivadavia
# Processing Record 16 of Set 13 | bristol
# Processing Record 17 of Set 13 | bambey
# Processing Record 18 of Set 13 | bentong
# Processing Record 19 of Set 13 | pucara
# Processing Record 20 of Set 13 | lolua
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 21 of Set 13 | aguimes
# Processing Record 22 of Set 13 | ust-nera
# Processing Record 23 of Set 13 | tucupita
# Processing Record 24 of Set 13 | gondanglegi
# Processing Record 25 of Set 13 | merauke
# Processing Record 26 of Set 13 | walvis bay
# Processing Record 27 of Set 13 | tiznit
# Processing Record 28 of Set 13 | orizona
# Processing Record 29 of Set 13 | suez
# Processing Record 30 of Set 13 | jega
# Processing Record 31 of Set 13 | sabaudia
# Processing Record 32 of Set 13 | leshan
# Processing Record 33 of Set 13 | bucerias
# Processing Record 34 of Set 13 | puerto penasco
# Processing Record 35 of Set 13 | muli
# Processing Record 36 of Set 13 | tamandare
# Processing Record 37 of Set 13 | north bend
# Processing Record 38 of Set 13 | beatrice
# Processing Record 39 of Set 13 | kieta
# Processing Record 40 of Set 13 | mizdah
# Processing Record 41 of Set 13 | haibowan
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 42 of Set 13 | shangrao
# Processing Record 43 of Set 13 | misterbianco
# Processing Record 44 of Set 13 | tomatlan
# Processing Record 45 of Set 13 | lakatoro
# Processing Record 46 of Set 13 | angra
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 47 of Set 13 | puerto narino
# Processing Record 48 of Set 13 | gat
# Processing Record 49 of Set 13 | penzance
# Processing Record 50 of Set 13 | makhachkala
# Processing Record 1 of Set 14 | maku
# Processing Record 2 of Set 14 | ambon
# Processing Record 3 of Set 14 | bolshoye murashkino
# Processing Record 4 of Set 14 | ulaangom
# Processing Record 5 of Set 14 | bozhou
# Processing Record 6 of Set 14 | middlebury
# Processing Record 7 of Set 14 | jalu
# Processing Record 8 of Set 14 | rongcheng
# Processing Record 9 of Set 14 | pyaozerskiy
# Processing Record 10 of Set 14 | odlabari
# Processing Record 11 of Set 14 | ballina
# Processing Record 12 of Set 14 | ayr
# Processing Record 13 of Set 14 | coronado
# Processing Record 14 of Set 14 | livingston
# Processing Record 15 of Set 14 | uvat
# Processing Record 16 of Set 14 | lebowakgomo
# Processing Record 17 of Set 14 | saint-joseph
# Processing Record 18 of Set 14 | chekhov
# Processing Record 19 of Set 14 | xichang
# Processing Record 20 of Set 14 | yanam
# Processing Record 21 of Set 14 | wattegama
# Processing Record 22 of Set 14 | kununurra
# Processing Record 23 of Set 14 | boa vista
# Processing Record 24 of Set 14 | yenagoa
# Processing Record 25 of Set 14 | khovu-aksy
# Processing Record 26 of Set 14 | kadykchan
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 27 of Set 14 | buraydah
# Processing Record 28 of Set 14 | joshimath
# Processing Record 29 of Set 14 | coahuayana
# Processing Record 30 of Set 14 | oak ridge
# Processing Record 31 of Set 14 | almaznyy
# Processing Record 32 of Set 14 | hualmay
# Processing Record 33 of Set 14 | jiangkou
# Processing Record 34 of Set 14 | sheltozero
# Processing Record 35 of Set 14 | mahibadhoo
# Processing Record 36 of Set 14 | imeni poliny osipenko
# Processing Record 37 of Set 14 | kirkuk
# Processing Record 38 of Set 14 | greece
# Processing Record 39 of Set 14 | rocha
# Processing Record 40 of Set 14 | kuala kedah
# Processing Record 41 of Set 14 | tayoltita
# Processing Record 42 of Set 14 | tres arroyos
# Processing Record 43 of Set 14 | cosala
# Processing Record 44 of Set 14 | temaraia
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 45 of Set 14 | bac can
# city not found..skipping...
# Traceback (most recent call last):
#   File "C:\Users\Granger\AppData\Local\Temp\ipykernel_20296\1274557768.py", line 36, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 46 of Set 14 | lumberton
# Processing Record 47 of Set 14 | illela
# Processing Record 48 of Set 14 | rabo de peixe
# Processing Record 49 of Set 14 | sibolga
# Processing Record 50 of Set 14 | sonamura
# Processing Record 1 of Set 15 | general salgado
# Processing Record 2 of Set 15 | beringovskiy
# Processing Record 3 of Set 15 | sturgis
# Processing Record 4 of Set 15 | fuyu
# Processing Record 5 of Set 15 | sarkand
# Processing Record 6 of Set 15 | itarema
# Processing Record 7 of Set 15 | ban tak
# Processing Record 8 of Set 15 | gimli
# Processing Record 9 of Set 15 | nuuk
# Processing Record 10 of Set 15 | hambantota
# Processing Record 11 of Set 15 | moerai
# Processing Record 12 of Set 15 | robinson
# Processing Record 13 of Set 15 | bestobe
# Processing Record 14 of Set 15 | tara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 654

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hobart -42.8794  147.3294     60.66        55          75
# 1         Watsa   3.0372   29.5355     66.88        94          99
# 2    Bredasdorp -34.5322   20.0403     73.65        52           0
# 3       Kushiro  42.9750  144.3747     40.64        70          97
# 4         Vaini -21.2000 -175.2000     78.96        89          75
# 5         Togul  53.4650   85.9128     -5.75        79          13
# 6  Puerto Ayora  -0.7393  -90.3518     68.56        90          89
# 7      Saldanha -33.0117   17.9442     74.75        45          13
# 8     Micheweni  -4.9667   39.8333     82.13        71          13
# 9       Mataura -46.1927  168.8643     59.49        79         100
#
#    Wind Speed Country Current Description
# 0       18.41      AU       broken clouds
# 1        2.04      CD     overcast clouds
# 2       14.72      ZA           clear sky
# 3        6.29      JP     overcast clouds
# 4        6.91      TO       broken clouds
# 5        0.58      RU          few clouds
# 6        4.97      EC     overcast clouds
# 7        0.78      ZA          few clouds
# 8        0.69      TZ          light rain
# 9        3.36      NZ     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_headings = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df2 = city_data_df[(city_data_headings)]

# Display sample data
city_data_df2.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hobart      AU -42.8794  147.3294     60.66        55          75
# 1         Watsa      CD   3.0372   29.5355     66.88        94          99
# 2    Bredasdorp      ZA -34.5322   20.0403     73.65        52           0
# 3       Kushiro      JP  42.9750  144.3747     40.64        70          97
# 4         Vaini      TO -21.2000 -175.2000     78.96        89          75
# 5         Togul      RU  53.4650   85.9128     -5.75        79          13
# 6  Puerto Ayora      EC  -0.7393  -90.3518     68.56        90          89
# 7      Saldanha      ZA -33.0117   17.9442     74.75        45          13
# 8     Micheweni      TZ  -4.9667   39.8333     82.13        71          13
# 9       Mataura      NZ -46.1927  168.8643     59.49        79         100
#
#    Wind Speed Current Description
# 0       18.41       broken clouds
# 1        2.04     overcast clouds
# 2       14.72           clear sky
# 3        6.29     overcast clouds
# 4        6.91       broken clouds
# 5        0.58          few clouds
# 6        4.97     overcast clouds
# 7        0.78          few clouds
# 8        0.69          light rain
# 9        3.36     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df2.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df2.to_csv(output_data_file, index_label="City_ID")
